# %% [markdown]
# <a href="https://colab.research.google.com/github/haritha-professional-25/TUTEDUDE_ASSIGNMENTS/blob/main/control_flow_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task1
# 1.
try:
  order_amount=int(input("Enter the order amount"))
  # 2.
  if order_amount >=2000:
    order_amount=order_amount-(order_amount*0.15)
  elif order_amount >= 1500 and order_amount<2000:
    order_amount=order_amount-(order_amount*0.10)
  elif order_amount >= 1000 and order_amount<1500:
    order_amount=order_amount-(order_amount*0.07)


  Final_amount=order_amount+(order_amount*0.05)

  print(f"Your subtotal is {order_amount}")
  print("Since you have added with a tax amout of 5%")
  print(f"Final amount is {Final_amount}")

except ValueError :
  print("Input should be neumeric")
# Out:
# Enter the order amount800
# Your subtotal is 800
# Since you have added with a tax amout of 5%
# Final amount is 840.0

# %%
# Task2
orders=[1200,2500,800,1750,3000]
print(f"Order Amount \t Discount Amount\t Sub Total \t Final amount")
print("----------------------------------------------------------------------")
discount_count=0
for order_amount in orders:
  if order_amount >=2000:
    discount="15%"
    discount_count+=1
    order_amount_updated=order_amount-(order_amount*0.15)
  elif order_amount >= 1500 and order_amount<2000:
    discount="10%"
    discount_count+=1
    order_amount_updated=order_amount-(order_amount*0.10)
  elif order_amount >= 1000 and order_amount<1500:
    discount="7%"
    discount_count+=1
    order_amount_updated=order_amount-(order_amount*0.07)
  else:
    discount="0%"
    order_amount_updated=order_amount
  Final_amount=order_amount_updated+(order_amount*0.05)
  print(f"{order_amount}\t\t\t {discount}\t\t {order_amount_updated}       \t {Final_amount}")


print("Number of orders with discount greater that 0%",discount_count)
# Out:
# Order Amount 	 Discount Amount	 Sub Total 	 Final amount
# ----------------------------------------------------------------------
# 1200			 7%		 1116.0       	 1176.0
# 2500			 15%		 2125.0       	 2250.0
# 800			 0%		 800       	 840.0
# 1750			 10%		 1575.0       	 1662.5
# 3000			 15%		 2550.0       	 2700.0
# Number of orders with discount greater that 0% 4

# %%
 # Task3
orders=[1200,2500,800,1750,3000]
while True:
  print("1.Add order amount")
  print("2.Show all orders")
  print("q.Quit")

  choice=input("Enter your choice")
  if choice.lower() == "q":
    print("END")
    break
  elif choice == "1":
    amount=int(input("Enter the order amount"))
    orders.append(amount)
  elif choice == "2":
    print(f"Order Amount \t Final amount")
    print("----------------------------------------------------------------------")
    for order_amount in orders:
      if order_amount >=2000:
        order_amount_updated=order_amount-(order_amount*0.15)
      elif order_amount >= 1500 and order_amount<2000:
        order_amount_updated=order_amount-(order_amount*0.10)
      elif order_amount >= 1000 and order_amount<1500:
        order_amount_updated=order_amount-(order_amount*0.07)
      Final_amount=order_amount_updated+(order_amount*0.05)
      print(f"{order_amount}\t\t{order_amount_updated}")

    else:
      continue
# Out:
# 1.Add order amount
# 2.Show all orders
# q.Quit
# Enter your choice1
# Enter the order amount2000
# 1.Add order amount
# 2.Show all orders
# q.Quit
# Enter your choice2
# Order Amount 	 Final amount
# ----------------------------------------------------------------------
# 1200		1116.0
# 2500		2125.0
# 800		2125.0
# 1750		1575.0
# 3000		2550.0
# 2000		1700.0
# 1.Add order amount
# 2.Show all orders
# q.Quit
# Enter your choiceq
# END

# %%
#Task5
daily=[200,150,0,400,50,-1,300]
total_sales=0
for i in daily:
  if i==-1:
    break
  elif i==0:
    continue
  elif i>0:
    total_sales+=i
print(total_sales)
# Out:
# 800
